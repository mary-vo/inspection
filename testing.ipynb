# %%
import pandas as pd

# %% [markdown]
# - write a function where I can pass these files in, read them, convert header to lowercase, and values to lowercase

# %%
lou_inspection = pd.read_excel("louisville_inspection.xlsx")
lou_inspection.columns = lou_inspection.columns.str.lower()
lou_inspection = lou_inspection.applymap(lambda s: s.lower() if type(s) == str else s)
lou_inspection
# Out:
#        establishmentid  inspectionid ins_typedesc          establishmentname  \
# 0                29956       1684470      regular                  cvs #6211
# 1                29967       1699737      regular     neighborhood food mart
# 2                29979       1698679      regular          circle k #4700075
# 3                29979       1698680      regular          circle k #4700075
# 4                29979       1731827      regular          circle k #4700075
# ...                ...           ...          ...                        ...
# 11225           118688       1758428        other        gringos food trucks
# 11226           118697       1758467        other    frickled pickle express
# 11227           118710       1758790        other  tienda latinoamericano #3
# 11228           118710       1758791        other  tienda latinoamericano #3
# 11229           118711       1758835        other  trio sports bar and grill
#
# ...

# %%
yelp_df = pd.read_excel("yelp_places.xlsx")
yelp_df = yelp_df.applymap(lambda s: s.lower() if type(s) == str else s)
yelp_df
# Out:
#                          id  \
# 0    wi0imyhbxiy6am6gc7cfwg
# 1    21nt4st1rxsutjsu9s5u4w
# 2    odtehpnf_efyedaos1tkbg
# 3    ip1u6lnesn-coxw9h0j0da
# 4    9mn8qellyejdr4l_ufp2lw
# ..                      ...
# 995  p4acvxz9mosyywpqtpjteg
# 996  gbrx9_xc_oasfvqz_b5hhq
# 997  exwynwbnmx6fcu8snuf2rg
# 998  zmmrzwm1a6ndegv2fchxkg
# 999  bcgtatvxljvxmdephl0cpg
#
#                                                  alias  \
# 0                               hammerheads-louisville
# 1                               the-eagle-louisville-2
# 2                          north-of-bourbon-louisville
# 3    doc-crows-southern-smokehouse-and-raw-bar-loui...
# 4    copper-and-kings-rooftop-bar-and-restaurant-lo...
# ..                                                 ...
# 995                            thelmas-deli-louisville
# 996                              max-orient-louisville
# 997                          king-gyros-saint-matthews
# 998                    diegos-mexican-grill-louisville
# ...

# %%
joined = pd.concat([lou_inspection.rename(columns={'EstablishmentName':'name'}),yelp_df], ignore_index=True)
joined.to_excel("output.xlsx")

# %%
merged = pd.merge(lou_inspection,yelp_df, left_on=['establishmentname','address'], right_on=['name','location.address1'])
merged.to_excel("output.xlsx")
