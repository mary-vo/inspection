# %%
import geopandas as gpd
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
louisville_map = gpd.read_file('Jefferson_County_KY_Street_Centerlines.shp')
louisville_map.head(10)
# Out:
#    OBJECTID  RWCOMPKEY  RWCOMPKEYP LOW_ADDRES  FROM_ADDRE  TO_ADDRESS  LFROM  \
# 0         1      24074           0       6300        6300        6399   6301
# 1         2      20311           0       1600        1600        1619   1601
# 2         3      21109           0       1700        1700        1705   1701
# 3         4      20926           0        505         505         519    505
# 4         5      19036           0        730         730         799    731
# 5         6       3788           0        603         603         635    603
# 6         7      32812           0      10600       10600       10699  10600
# 7         8      29731           0      10312       10312       10399  10313
# 8         9      31978           0      11100       11100       11124  11101
# 9        10       4002           0       2500        2500        2515   2501
#
#      LTO  RFROM    RTO  SIFID SIFCODE             ROADNAME AVDIR AVPRETYPE  \
# ...

# %%
pd.set_option('display.max_columns', None)
louisville_map = gpd.read_file('Jefferson_County_KY_Parcels.shp')
louisville_map.head(10)
# Out:
#    OBJECTID      PARCELID  PARCEL_TYP       LRSN  \
# 0         1  000100050000           0        1.0
# 1         2  0001SROW0000          16   710001.0
# 2         3  314200190000           0  1002288.0
# 3         4  314200180000           0  1002289.0
# 4         5  314200200000           0  1002290.0
# 5         6  314200150000           0  1002291.0
# 6         7  314200170000           0  1002292.0
# 7         8  314200140000           0  1002293.0
# 8         9  3142SROW0000          16  1002294.0
# 9        10  314200130000           0  1002297.0
#
#                                  GLOBALID     SHAPEAREA     SHAPELEN  \
# 0  {3BC2967E-39A3-4911-B839-2D9DACBD3392}  3.433593e+06  9372.963539
# 1  {D6F20CFD-A861-4BED-8832-CB68CD9305FF}  1.092827e+05  5795.230681
# 2  {5F400BE0-0C37-4DB5-941E-4B0F483E9007}  2.607192e+05  2307.009559
# 3  {F02FF34B-BFFA-4F17-A1FD-6F83A103BD69}  1.094183e+05  1601.115627
# 4  {C602FE3F-A3E7-4C52-96BB-C6E63A85F132}  2.970041e+05  2558.060057
# ...

# %%
pd.set_option('display.max_columns', None)
louisville_map = gpd.read_file('Jefferson_County_KY_Address_Points_2021.shp')
filtered_rows = louisville_map[louisville_map['ParcelId'] == '041D01050000']
filtered_rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Mary's PC\GIT\Code Louisville\inspection\venv\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\Mary's PC\GIT\Code Louisville\inspection\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Mary's PC\GIT\Code Louisville\inspection\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ParcelId'
#
# ...

# %%
pd.set_option('display.max_columns', None)
louisville_map = gpd.read_file('Jefferson_County_KY_Address_Points_2021.shp', rows=5)
filtered_rows = louisville_map[louisville_map['ParcelId'] == '041D01050000']

# %%
louisville_map.head(5)
# Out:
#    OBJECTID       ADDRESS SIFCODE  HOUSENO  HAFHOUSE  APT  DIR   STRNAME TYPE  \
# 0         1     2499 2110    2499     2110       NaN  NaN    W  GAULBERT  AVE
# 1         2     2499 2113    2499     2113       NaN  NaN    W  GAULBERT  AVE
# 2         3   2327  945 1    2327      945       NaN    1  NaN  FRANKLIN   ST
# 3         4  7553  740 4C    7553      740       NaN   4C  NaN      ZORN  AVE
# 4         5     8199 1221    8199     1221       NaN  NaN  NaN     RIVER   RD
#
#        PARCELID     LRSN     SITECAD ZIPCODE AVDIR  AVPRETYPE  AVSTNAME  \
# 0  041D01050000   100427  1110157370   40210     W        NaN  GAULBERT
# 1  041D01600000    99535  1110157172   40210     W        NaN  GAULBERT
# 2  019E00570000  8002584  1110341647   40206   NaN        NaN  FRANKLIN
# 3  088S00K10000  9709780  1110217668   40206   NaN        NaN      ZORN
# 4  018G00110000    33900  1110183732   40206   NaN        NaN     RIVER
#
# ...
